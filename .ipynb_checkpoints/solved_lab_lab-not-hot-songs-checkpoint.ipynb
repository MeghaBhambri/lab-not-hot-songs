# %%
import pandas as pd

# %%
#read csv file(not_top_100)
not_top_100 = pd.read_csv("genres_v2.csv")
not_top_100 = not_top_100.sample(10000)
display(not_top_100.head())
# Out:
# C:\Users\Megha\AppData\Local\Temp\ipykernel_1504\2562102582.py:2: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   not_top_100 = pd.read_csv("genres_v2.csv")
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 15556         0.838   0.626    0    -4.214     1       0.0396       0.00211
# 14423         0.611   0.478    0    -5.839     1       0.1070       0.03500
# 20743         0.744   0.697   11    -5.063     0       0.1970       0.01060
# 15109         0.823   0.703    8    -2.691     1       0.2980       0.01610
# 42067         0.543   0.742    8    -6.434     1       0.0382       0.00183
#
#        instrumentalness  liveness  valence  ...                      id  \
# 15556          0.000059    0.0221    0.108  ...  5YZRZqEkrteLmxvseHnQ2K
# 14423          0.000000    0.1070    0.138  ...  1AH60dMaEfNjzDoUIFwIQi
# 20743          0.000000    0.0842    0.767  ...  17husT8tMWaBHcQqUpYDZQ
# ...

# %%
#read csv file
top_100 = pd.read_csv("top_100.csv")
display(top_100.head())
# Out:
#                    Songs                               Artists
# 0     Paint The Town Red                              Doja Cat
# 1                 Snooze                                   SZA
# 2               Fast Car                            Luke Combs
# 3           Cruel Summer                          Taylor Swift
# 4  I Remember Everything  Zach Bryan Featuring Kacey Musgraves

# %%
# remove the songs from "non_top_100" that are also in "top_100"
not_top_100 = not_top_100[~not_top_100['song_name'].isin(top_100['Songs'])]

# %%
display(not_top_100.head())
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 15556         0.838   0.626    0    -4.214     1       0.0396       0.00211
# 14423         0.611   0.478    0    -5.839     1       0.1070       0.03500
# 20743         0.744   0.697   11    -5.063     0       0.1970       0.01060
# 15109         0.823   0.703    8    -2.691     1       0.2980       0.01610
# 42067         0.543   0.742    8    -6.434     1       0.0382       0.00183
#
#        instrumentalness  liveness  valence  ...                      id  \
# 15556          0.000059    0.0221    0.108  ...  5YZRZqEkrteLmxvseHnQ2K
# 14423          0.000000    0.1070    0.138  ...  1AH60dMaEfNjzDoUIFwIQi
# 20743          0.000000    0.0842    0.767  ...  17husT8tMWaBHcQqUpYDZQ
# 15109          0.000001    0.2940    0.260  ...  50I7FNN2rl2rWiNwGxS146
# 42067          0.133000    0.0507    0.720  ...  4RXQuHkARwRhSccG0L9M5W
#
#                                         uri  \
# ...

# %%
not_top_100.isna().sum()
# Out:
# danceability           0
# energy                 0
# key                    0
# loudness               0
# mode                   0
# speechiness            0
# acousticness           0
# instrumentalness       0
# liveness               0
# valence                0
# tempo                  0
# type                   0
# id                     0
# uri                    0
# track_href             0
# analysis_url           0
# duration_ms            0
# time_signature         0
# genre                  0
# song_name           4860
# Unnamed: 0          5136
# title               5136
# dtype: int64

# %%
not_top_100 = not_top_100.dropna(subset=['song_name'])

# %%
not_top_100.isna().sum()
# Out:
# danceability           0
# energy                 0
# key                    0
# loudness               0
# mode                   0
# speechiness            0
# acousticness           0
# instrumentalness       0
# liveness               0
# valence                0
# tempo                  0
# type                   0
# id                     0
# uri                    0
# track_href             0
# analysis_url           0
# duration_ms            0
# time_signature         0
# genre                  0
# song_name              0
# Unnamed: 0          5134
# title               5134
# dtype: int64

# %%
len(not_top_100)
# Out:
# 5134

# %%
not_top_100.to_csv('not_top_100.csv', index = False)
